# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
raw_data = {'first_name': ['Ethan', 'Olivia', 'Lucas', 'Sophia', 'Noah'],
            'last_name': ['Carter', 'Bennett', 'Walker', 'Turner', 'Anderson'],
            'female': [0, 1, 0, 1, 0],
            'age': [12, 13, 15, 10, 17],
            'preTestScore': [5, 24, 40, 8, 15],
            'postTestScore': [6, 40, 50, 44, 23]}
df = pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Ethan    Carter       0   12             5              6
# 1     Olivia   Bennett       1   13            24             40
# 2      Lucas    Walker       0   15            40             50
# 3     Sophia    Turner       1   10             8             44
# 4       Noah  Anderson       0   17            15             23

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df_long= df.melt(id_vars="age", value_vars=["preTestScore", "postTestScore"],
                 var_name="TestScore", value_name="Score")
sns.scatterplot(x="age", y="Score", hue="TestScore", data=df_long)
plt.title("Score by age")
plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
df_post = df_post.melt(id_vars="age", value_vars=["preTestScore", "postTestScore"],
                 var_name="TestScore", value_name="Score")
# Out:
#    age      TestScore  Score
# 0   12   preTestScore      5
# 1   13   preTestScore     24
# 2   15   preTestScore     40
# 3   10   preTestScore      8
# 4   17   preTestScore     15
# 5   12  postTestScore      6
# 6   13  postTestScore     40
# 7   15  postTestScore     50
# 8   10  postTestScore     44
# 9   17  postTestScore     23

# %%
plt.scatter(df.preTestScore, df.postTestScore, s= df.postTestScore * 4.5, c = df.female)

plt.title("preTestScore_postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('preTestScore')
# Out:
# Text(0, 0.5, 'preTestScore')

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
create histogram of preTestScore by sex

# %%
import seaborn as sns
sns.histplot(data= df, x="female", y="preTestScore")
plt.xlabel("male/female")
plt.title("histogram of preTestScore by sex")
plt.show()
