# %% [markdown]
# **[개념]**

# %% [markdown]
# ```
# 앙상블 학습
# 보팅 앙상블: 여러 모델의 예측 결과를 모아서 최종 결과를 결정하는 방식
#
# 1. 보팅 유형
#
#
# *   하드 보팅: 각 모델이 예측한 '클래스'로 투표
# (가장 많이 나온 클래스 선택)
# *   소프트 보팅: 각 모델의 '확률값'을 평균내서 결정
# (하드보팅처럼 다수결이 아니라 평균을 사용)
# (하드 보팅보다 성능 좋음)
#
#
#
#
#
# 2. 보팅 분류기
#
# : 여러개의 분류 모델을 사용하여 최종 예측을 결정하는 앙상블 방법
# (여러 모델들을 함께 사용해서 오차를 줄이고 성능 향상 가능)
#  VotingClassifier
# -> from sklearn.ensemble import VotingClassifier
#
# 1) 개별 모델 생성(ex. LR & KNN)
# 객체1 = LogisticRegression( )
# 객체2 =  KNeighborsClassifier( )
#
# 2) 생성한 모델 객체 바탕으로 보팅 분류기 생성
# vo_clf = VotingClassifier(
#     estimators=[('모델이름', 객체), ('모델 이름', 객체)],
#     voting='보팅 방식(soft/hard)'
# )
#
# 3) 학습 및 예측
# fit(  ): 학습
# predict(  ) : test 데이터 기반 예측
# accuracy_score(test 데이터 , 예측값(predict()))): 실제값과 예측값을 비교해서 정확도 계산
#
#
#
# 3. 랜덤 포레스트
# : 여러 개의 결정트리를 만들어서 결과를 합치는 앙상블 모델
#
# from sklearn.ensemble import RandomForestClassifier
#  RandomForestClassifier(random_state= , max_depth= )
# cf) 재수행 할때마다 동일한 예측 결과 출력 희망 시 -> random_state=0 로 설정
#     n_jobs=-1 추가 시 모든 cpu코어로 학습 가능
#
#
#
#
#
# ```

# %% [markdown]
# **[필사]**

# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer = load_breast_cancer()

data_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
#
# [3 rows x 30 columns]

# %%
# 개별 모델은 로지스틱 회귀와 KNN임.
lr_clf = LogisticRegression(solver='liblinear')
knn_clf = KNeighborsClassifier(n_neighbors=8)

# 개별 모델을 소프트 보팅 기반의 앙상블 모델로 구현한 분류기
vo_clf = VotingClassifier(estimators=[('LR', lr_clf), ('KNN', knn_clf)], voting='soft')

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target,
                                                    test_size=0.2, random_state=156)
# VotingClassifier 학습/예측/평가.
vo_clf.fit(X_train, y_train)
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test, pred)))
# 개별 모델의 학습/예측/평가.
classifiers = [lr_clf, knn_clf]
for classifier in classifiers:
  classifier.fit(X_train, y_train)
  pred = classifier.predict(X_test)
  class_name = classifier.__class__.__name__
  print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test, pred)))
# Out:
# Voting 분류기 정확도: 0.9561
# LogisticRegression 정확도: 0.9474
# KNeighborsClassifier 정확도: 0.9386

# %%
def get_new_feature_name_df(old_feature_name_df):
  feature_dup_df= pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                               columns=['dup_cnt'])
  feature_dup_df = feature_dup_df.reset_index()
  new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')

  new_feature_name_df['column_name']= new_feature_name_df[['column_name',
                                                          'dup_cnt']].apply(lambda x:
                                                                            x[0]+'_'+str(x[1])
                                                          if x[1]>0 else x[0], axis=1)

  new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
  return new_feature_name_df

# %%
import pandas as pd

def get_human_dataset():
  # 각데이터 파일은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당.
  feature_name_df = pd.read_csv('/content/features.txt', sep='\s+',
                                header=None, names=['column_index', 'column_name'])
  # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame으로 생성.
  new_feature_name_df = get_new_feature_name_df(feature_name_df)

  #DataFrame에 피처명을 칼럼으로 부여하기 위해 리스트 객체로 다시 변환
  feature_name = new_feature_name_df.iloc[:,1].values.tolist()

  # 학습 피처 데이터 세트와 테스트 피처 데이터를 DataFrame으로 로딩. 칼럼명은 feature_name 적용.
  X_train = pd.read_csv('/content/X_train.txt', sep='\s+', header=None, names=feature_name)
  X_test = pd.read_csv('/content/X_test.txt', sep='\s+', header=None, names=feature_name)

  # 학습 레이블과 테스트 레이블 데이터를 DataFrame으로 로딩하고, 칼럼명은 action으로 부여
  y_train = pd.read_csv('/content/y_train.txt', sep='\s+', header=None, names=['action'])
  y_test = pd.read_csv('/content/y_test.txt', sep='\s+', header=None, names=['action'])

  # 로드된 학습/테스트용 DataFrame을 모두 반환

  return X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = get_human_dataset()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_5730/1367971584.py:5: SyntaxWarning: invalid escape sequence '\s'
#   feature_name_df = pd.read_csv('/content/features.txt', sep='\s+',
# /tmp/ipykernel_5730/1367971584.py:14: SyntaxWarning: invalid escape sequence '\s'
#   X_train = pd.read_csv('/content/X_train.txt', sep='\s+', header=None, names=feature_name)
# /tmp/ipykernel_5730/1367971584.py:15: SyntaxWarning: invalid escape sequence '\s'
#   X_test = pd.read_csv('/content/X_test.txt', sep='\s+', header=None, names=feature_name)
# /tmp/ipykernel_5730/1367971584.py:18: SyntaxWarning: invalid escape sequence '\s'
#   y_train = pd.read_csv('/content/y_train.txt', sep='\s+', header=None, names=['action'])
# /tmp/ipykernel_5730/1367971584.py:19: SyntaxWarning: invalid escape sequence '\s'
#   y_test = pd.read_csv('/content/y_test.txt', sep='\s+', header=None, names=['action'])
# /tmp/ipykernel_5730/1657028298.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]>0 else x[0], axis=1)
# /tmp/ipykernel_5730/1657028298.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x[0]+'_'+str(x[1])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# 결정 트리에서 사용한 get_human_dataset()를 이용해 학습/테스트용 DataFrame 반환
X_train, X_test, y_train, y_test = get_human_dataset()

# 랜덤 포레스트 학습 및 별도의 테스트 세트로 예측 성능 평가
rf_clf = RandomForestClassifier(random_state=0, max_depth=8)
rf_clf.fit(X_train, y_train)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9220

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth': [1, 6, 24],
    'min_samples_leaf': [1, 6, 12],
    'min_samples_split': [2, 8, 16]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도:{0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 24, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 최고 예측 정확도:0.9154

# %%
rf_clf1 = RandomForestClassifier(n_estimators=100, min_samples_leaf=6, max_depth=16,
                                 min_samples_split=2, random_state=0)
rf_clf1.fit(X_train, y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test, pred)))
# Out:
# 예측 정확도: 0.9253

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values = rf_clf1.feature_importances_
ftr_imp
ortances= pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time
import warnings
warnings.filterwarnings('ignore')
X_train, X_test, y_train, y_test = get_human_dataset()

# GBM 수행 시간 측정을 위함. 시작 시간 설정.
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('GBM 정확도: {0:.4f}'.format(gb_accuracy))
print("GBM 수행시간: {0:.1f} 초".format(time.time() - start_time))
# Out:
# GBM 정확도: 0.9379
# GBM 수행시간: 1475.6 초

# %%
# pip install xgboost==1.5.0

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
import xgboost

print(xgboost.__version__)
# Out:
# 3.2.0

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()
features = dataset.data
labels = dataset.target

cancer_df = pd.DataFrame(data=features, columns=dataset.feature_names)
cancer_df['target']= labels
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# cancer_df에서 feature용 DataFrame과 Label용 Series 객체 추출
# 맨 마지막 칼럼이 Label임. Feature용 DataFrame은 cancer_df의 첫번째 칼럼에서 맨 마지막 두번째 칼럼까지를 :-1 슬라이싱으로 추출.
X_features = cancer_df.iloc[:, :-1]
y_label =cancer_df.iloc[:, -1]

# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2,
                                                    random_state=156)
# 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리
X_tr, X_val, y_tr, y_val=train_test_split(X_train, y_train, test_size=0.1, random_state=156)
print(X_train.shape, X_test.shape)
print(X_tr.shape, X_val.shape)
# Out:
# (455, 30) (114, 30)
# (409, 30) (46, 30)

# %%
# 만약 구버전 XGBoost에서 DataFrame으로 DMatrix 생성이 안 될 경우 X_train.values로 넘파이 변환.
# 학습, 검증, 테스트용 DMatrix를 생성.
dtr = xgb.DMatrix(data=X_train.values, label=y_train.values)
dval = xgb.DMatrix(data=X_val.values, label=y_val.values)
dtest = xgb.DMatrix(data=X_test.values, label=y_test.values)

# %%
params = {'max_depth':3,
          'eta': 0.05,
          'objective':'binary:logistic',
          'eval_metric':'logloss'}
num_rounds=400

# %%
# 학습 데이터 셋은 'train 또는 평가 데이터 셋은 'eval'로 명기합니다.
eval_list = [(dtr, 'train'),(dval, 'eval')] # 또는 eval_list = [(dval, 'eval)] 만 명기해도 무방.

# 하이퍼 파라미터와 early stopping 파라미터를 train()함수의 파라미터로 전달
xgb_model = xgb.train(params = params, dtrain=dtr, num_boost_round = num_rounds, \
                      early_stopping_rounds=50, evals=eval_list)
# Out:
# [0]	train-logloss:0.62418	eval-logloss:0.62140
# [1]	train-logloss:0.58700	eval-logloss:0.59120
# [2]	train-logloss:0.55250	eval-logloss:0.55979
# [3]	train-logloss:0.52176	eval-logloss:0.53436
# [4]	train-logloss:0.49368	eval-logloss:0.51236
# [5]	train-logloss:0.46791	eval-logloss:0.49087
# [6]	train-logloss:0.44332	eval-logloss:0.47039
# [7]	train-logloss:0.42042	eval-logloss:0.44910
# [8]	train-logloss:0.39932	eval-logloss:0.43140
# [9]	train-logloss:0.37979	eval-logloss:0.41363
# [10]	train-logloss:0.36135	eval-logloss:0.39636
# [11]	train-logloss:0.34433	eval-logloss:0.38190
# [12]	train-logloss:0.32849	eval-logloss:0.36841
# [13]	train-logloss:0.31330	eval-logloss:0.35375
# [14]	train-logloss:0.29943	eval-logloss:0.34185
# [15]	train-logloss:0.28608	eval-logloss:0.32878
# [16]	train-logloss:0.27384	eval-logloss:0.31917
# [17]	train-logloss:0.26206	eval-logloss:0.30753
# [18]	train-logloss:0.25119	eval-logloss:0.29764
# [19]	train-logloss:0.24091	eval-logloss:0.28818
# [20]	train-logloss:0.23125	eval-logloss:0.27893
# [21]	train-logloss:0.22186	eval-logloss:0.27008
# [22]	train-logloss:0.21303	eval-logloss:0.26193
# [23]	train-logloss:0.20483	eval-logloss:0.25507
# [24]	train-logloss:0.19690	eval-logloss:0.24790
# [25]	train-logloss:0.18957	eval-logloss:0.24063
# [26]	train-logloss:0.18262	eval-logloss:0.23468
# [27]	train-logloss:0.17590	eval-logloss:0.22717
# [28]	train-logloss:0.16969	eval-logloss:0.22104
# [29]	train-logloss:0.16373	eval-logloss:0.21524
# [30]	train-logloss:0.15767	eval-logloss:0.20915
# [31]	train-logloss:0.15198	eval-logloss:0.20314
# [32]	train-logloss:0.14674	eval-logloss:0.19728
# [33]	train-logloss:0.14195	eval-logloss:0.19235
# [34]	train-logloss:0.13700	eval-logloss:0.18724
# [35]	train-logloss:0.13251	eval-logloss:0.18212
# [36]	train-logloss:0.12827	eval-logloss:0.17756
# [37]	train-logloss:0.12429	eval-logloss:0.17363
# [38]	train-logloss:0.12017	eval-logloss:0.16894
# [39]	train-logloss:0.11637	eval-logloss:0.16547
# [40]	train-logloss:0.11268	eval-logloss:0.16132
# [41]	train-logloss:0.10935	eval-logloss:0.15754
# [42]	train-logloss:0.10608	eval-logloss:0.15437
# [43]	train-logloss:0.10273	eval-logloss:0.14976
# [44]	train-logloss:0.09961	eval-logloss:0.14589
# [45]	train-logloss:0.09664	eval-logloss:0.14253
# [46]	train-logloss:0.09381	eval-logloss:0.13841
# [47]	train-logloss:0.09106	eval-logloss:0.13494
# [48]	train-logloss:0.08842	eval-logloss:0.13127
# [49]	train-logloss:0.08595	eval-logloss:0.12834
# [50]	train-logloss:0.08356	eval-logloss:0.12530
# [51]	train-logloss:0.08136	eval-logloss:0.12304
# [52]	train-logloss:0.07916	eval-logloss:0.11993
# [53]	train-logloss:0.07695	eval-logloss:0.11676
# [54]	train-logloss:0.07484	eval-logloss:0.11441
# [55]	train-logloss:0.07302	eval-logloss:0.11236
# [56]	train-logloss:0.07115	eval-logloss:0.10964
# [57]	train-logloss:0.06928	eval-logloss:0.10750
# [58]	train-logloss:0.06749	eval-logloss:0.10485
# [59]	train-logloss:0.06571	eval-logloss:0.10225
# [60]	train-logloss:0.06407	eval-logloss:0.10049
# [61]	train-logloss:0.06257	eval-logloss:0.09878
# [62]	train-logloss:0.06109	eval-logloss:0.09614
# [63]	train-logloss:0.05976	eval-logloss:0.09464
# [64]	train-logloss:0.05834	eval-logloss:0.09315
# [65]	train-logloss:0.05706	eval-logloss:0.09138
# [66]	train-logloss:0.05591	eval-logloss:0.09012
# [67]	train-logloss:0.05463	eval-logloss:0.08879
# [68]	train-logloss:0.05345	eval-logloss:0.08658
# [69]	train-logloss:0.05213	eval-logloss:0.08426
# [70]	train-logloss:0.05099	eval-logloss:0.08308
# [71]	train-logloss:0.04994	eval-logloss:0.08108
# [72]	train-logloss:0.04900	eval-logloss:0.07973
# [73]	train-logloss:0.04811	eval-logloss:0.07878
# [74]	train-logloss:0.04707	eval-logloss:0.07785
# [75]	train-logloss:0.04616	eval-logloss:0.07643
# [76]	train-logloss:0.04524	eval-logloss:0.07530
# [77]	train-logloss:0.04432	eval-logloss:0.07447
# [78]	train-logloss:0.04355	eval-logloss:0.07360
# [79]	train-logloss:0.04275	eval-logloss:0.07298
# [80]	train-logloss:0.04194	eval-logloss:0.07196
# [81]	train-logloss:0.04113	eval-logloss:0.07081
# [82]	train-logloss:0.04041	eval-logloss:0.07027
# [83]	train-logloss:0.03949	eval-logloss:0.06924
# [84]	train-logloss:0.03877	eval-logloss:0.06773
# [85]	train-logloss:0.03811	eval-logloss:0.06642
# [86]	train-logloss:0.03741	eval-logloss:0.06539
# [87]	train-logloss:0.03681	eval-logloss:0.06418
# [88]	train-logloss:0.03613	eval-logloss:0.06300
# [89]	train-logloss:0.03550	eval-logloss:0.06202
# [90]	train-logloss:0.03494	eval-logloss:0.06090
# [91]	train-logloss:0.03428	eval-logloss:0.05982
# [92]	train-logloss:0.03357	eval-logloss:0.05908
# [93]	train-logloss:0.03301	eval-logloss:0.05820
# [94]	train-logloss:0.03233	eval-logloss:0.05720
# [95]	train-logloss:0.03177	eval-logloss:0.05639
# [96]	train-logloss:0.03124	eval-logloss:0.05548
# [97]	train-logloss:0.03078	eval-logloss:0.05454
# [98]	train-logloss:0.03030	eval-logloss:0.05406
# [99]	train-logloss:0.02973	eval-logloss:0.05312
# [100]	train-logloss:0.02928	eval-logloss:0.05265
# [101]	train-logloss:0.02874	eval-logloss:0.05153
# [102]	train-logloss:0.02832	eval-logloss:0.05090
# [103]	train-logloss:0.02782	eval-logloss:0.04993
# [104]	train-logloss:0.02737	eval-logloss:0.04876
# [105]	train-logloss:0.02694	eval-logloss:0.04803
# [106]	train-logloss:0.02654	eval-logloss:0.04736
# [107]	train-logloss:0.02608	eval-logloss:0.04686
# [108]	train-logloss:0.02571	eval-logloss:0.04590
# [109]	train-logloss:0.02537	eval-logloss:0.04531
# [110]	train-logloss:0.02498	eval-logloss:0.04431
# [111]	train-logloss:0.02457	eval-logloss:0.04396
# [112]	train-logloss:0.02424	eval-logloss:0.04333
# [113]	train-logloss:0.02385	eval-logloss:0.04292
# [114]	train-logloss:0.02351	eval-logloss:0.04210
# [115]	train-logloss:0.02314	eval-logloss:0.04179
# [116]	train-logloss:0.02281	eval-logloss:0.04091
# [117]	train-logloss:0.02247	eval-logloss:0.04045
# [118]	train-logloss:0.02219	eval-logloss:0.03996
# [119]	train-logloss:0.02188	eval-logloss:0.03976
# [120]	train-logloss:0.02158	eval-logloss:0.03927
# [121]	train-logloss:0.02129	eval-logloss:0.03854
# [122]	train-logloss:0.02099	eval-logloss:0.03813
# [123]	train-logloss:0.02074	eval-logloss:0.03769
# [124]	train-logloss:0.02049	eval-logloss:0.03732
# [125]	train-logloss:0.02024	eval-logloss:0.03708
# [126]	train-logloss:0.01997	eval-logloss:0.03635
# [127]	train-logloss:0.01974	eval-logloss:0.03594
# [128]	train-logloss:0.01949	eval-logloss:0.03559
# [129]	train-logloss:0.01928	eval-logloss:0.03551
# [130]	train-logloss:0.01907	eval-logloss:0.03505
# [131]	train-logloss:0.01882	eval-logloss:0.03453
# [132]	train-logloss:0.01860	eval-logloss:0.03419
# [133]	train-logloss:0.01840	eval-logloss:0.03390
# [134]	train-logloss:0.01820	eval-logloss:0.03357
# [135]	train-logloss:0.01800	eval-logloss:0.03330
# [136]	train-logloss:0.01786	eval-logloss:0.03313
# [137]	train-logloss:0.01768	eval-logloss:0.03286
# [138]	train-logloss:0.01749	eval-logloss:0.03258
# [139]	train-logloss:0.01730	eval-logloss:0.03242
# [140]	train-logloss:0.01713	eval-logloss:0.03217
# [141]	train-logloss:0.01697	eval-logloss:0.03194
# [142]	train-logloss:0.01682	eval-logloss:0.03172
# [143]	train-logloss:0.01665	eval-logloss:0.03136
# [144]	train-logloss:0.01650	eval-logloss:0.03114
# [145]	train-logloss:0.01634	eval-logloss:0.03091
# [146]	train-logloss:0.01620	eval-logloss:0.03072
# [147]	train-logloss:0.01603	eval-logloss:0.03058
# [148]	train-logloss:0.01589	eval-logloss:0.03036
# [149]	train-logloss:0.01576	eval-logloss:0.03017
# [150]	train-logloss:0.01562	eval-logloss:0.03009
# [151]	train-logloss:0.01553	eval-logloss:0.02986
# [152]	train-logloss:0.01538	eval-logloss:0.02948
# [153]	train-logloss:0.01525	eval-logloss:0.02928
# [154]	train-logloss:0.01508	eval-logloss:0.02913
# [155]	train-logloss:0.01496	eval-logloss:0.02906
# [156]	train-logloss:0.01486	eval-logloss:0.02880
# [157]	train-logloss:0.01475	eval-logloss:0.02868
# [158]	train-logloss:0.01465	eval-logloss:0.02865
# [159]	train-logloss:0.01454	eval-logloss:0.02862
# [160]	train-logloss:0.01444	eval-logloss:0.02847
# [161]	train-logloss:0.01432	eval-logloss:0.02829
# [162]	train-logloss:0.01424	eval-logloss:0.02808
# [163]	train-logloss:0.01410	eval-logloss:0.02795
# [164]	train-logloss:0.01400	eval-logloss:0.02778
# [165]	train-logloss:0.01386	eval-logloss:0.02742
# [166]	train-logloss:0.01374	eval-logloss:0.02725
# [167]	train-logloss:0.01362	eval-logloss:0.02696
# [168]	train-logloss:0.01354	eval-logloss:0.02673
# [169]	train-logloss:0.01346	eval-logloss:0.02676
# [170]	train-logloss:0.01337	eval-logloss:0.02674
# [171]	train-logloss:0.01330	eval-logloss:0.02658
# [172]	train-logloss:0.01320	eval-logloss:0.02637
# [173]	train-logloss:0.01309	eval-logloss:0.02607
# [174]	train-logloss:0.01302	eval-logloss:0.02596
# [175]	train-logloss:0.01291	eval-logloss:0.02581
# [176]	train-logloss:0.01282	eval-logloss:0.02562
# [177]	train-logloss:0.01275	eval-logloss:0.02558
# [178]	train-logloss:0.01268	eval-logloss:0.02533
# [179]	train-logloss:0.01258	eval-logloss:0.02504
# [180]	train-logloss:0.01251	eval-logloss:0.02494
# [181]	train-logloss:0.01245	eval-logloss:0.02480
# [182]	train-logloss:0.01236	eval-logloss:0.02473
# [183]	train-logloss:0.01227	eval-logloss:0.02444
# [184]	train-logloss:0.01221	eval-logloss:0.02441
# [185]	train-logloss:0.01215	eval-logloss:0.02421
# [186]	train-logloss:0.01206	eval-logloss:0.02396
# [187]	train-logloss:0.01200	eval-logloss:0.02382
# [188]	train-logloss:0.01193	eval-logloss:0.02376
# [189]	train-logloss:0.01186	eval-logloss:0.02366
# [190]	train-logloss:0.01179	eval-logloss:0.02359
# [191]	train-logloss:0.01170	eval-logloss:0.02333
# [192]	train-logloss:0.01164	eval-logloss:0.02320
# [193]	train-logloss:0.01157	eval-logloss:0.02314
# [194]	train-logloss:0.01151	eval-logloss:0.02305
# [195]	train-logloss:0.01143	eval-logloss:0.02281
# [196]	train-logloss:0.01138	eval-logloss:0.02269
# [197]	train-logloss:0.01131	eval-logloss:0.02263
# [198]	train-logloss:0.01126	eval-logloss:0.02251
# [199]	train-logloss:0.01121	eval-logloss:0.02234
# [200]	train-logloss:0.01114	eval-logloss:0.02210
# [201]	train-logloss:0.01108	eval-logloss:0.02201
# [202]	train-logloss:0.01103	eval-logloss:0.02190
# [203]	train-logloss:0.01097	eval-logloss:0.02176
# [204]	train-logloss:0.01089	eval-logloss:0.02151
# [205]	train-logloss:0.01084	eval-logloss:0.02140
# [206]	train-logloss:0.01079	eval-logloss:0.02127
# [207]	train-logloss:0.01072	eval-logloss:0.02106
# [208]	train-logloss:0.01068	eval-logloss:0.02104
# [209]	train-logloss:0.01061	eval-logloss:0.02103
# [210]	train-logloss:0.01055	eval-logloss:0.02090
# [211]	train-logloss:0.01049	eval-logloss:0.02068
# [212]	train-logloss:0.01044	eval-logloss:0.02060
# [213]	train-logloss:0.01039	eval-logloss:0.02059
# [214]	train-logloss:0.01032	eval-logloss:0.02039
# [215]	train-logloss:0.01028	eval-logloss:0.02028
# [216]	train-logloss:0.01024	eval-logloss:0.02018
# [217]	train-logloss:0.01019	eval-logloss:0.02013
# [218]	train-logloss:0.01013	eval-logloss:0.01994
# [219]	train-logloss:0.01008	eval-logloss:0.01987
# [220]	train-logloss:0.01004	eval-logloss:0.01978
# [221]	train-logloss:0.01000	eval-logloss:0.01963
# [222]	train-logloss:0.00994	eval-logloss:0.01944
# [223]	train-logloss:0.00989	eval-logloss:0.01944
# [224]	train-logloss:0.00985	eval-logloss:0.01937
# [225]	train-logloss:0.00982	eval-logloss:0.01930
# [226]	train-logloss:0.00976	eval-logloss:0.01913
# [227]	train-logloss:0.00972	eval-logloss:0.01913
# [228]	train-logloss:0.00969	eval-logloss:0.01904
# [229]	train-logloss:0.00965	eval-logloss:0.01896
# [230]	train-logloss:0.00962	eval-logloss:0.01886
# [231]	train-logloss:0.00956	eval-logloss:0.01869
# [232]	train-logloss:0.00952	eval-logloss:0.01870
# [233]	train-logloss:0.00950	eval-logloss:0.01867
# [234]	train-logloss:0.00946	eval-logloss:0.01860
# [235]	train-logloss:0.00942	eval-logloss:0.01852
# [236]	train-logloss:0.00939	eval-logloss:0.01839
# [237]	train-logloss:0.00936	eval-logloss:0.01836
# [238]	train-logloss:0.00930	eval-logloss:0.01823
# [239]	train-logloss:0.00926	eval-logloss:0.01817
# [240]	train-logloss:0.00921	eval-logloss:0.01799
# [241]	train-logloss:0.00918	eval-logloss:0.01791
# [242]	train-logloss:0.00916	eval-logloss:0.01794
# [243]	train-logloss:0.00912	eval-logloss:0.01788
# [244]	train-logloss:0.00907	eval-logloss:0.01771
# [245]	train-logloss:0.00904	eval-logloss:0.01769
# [246]	train-logloss:0.00900	eval-logloss:0.01757
# [247]	train-logloss:0.00897	eval-logloss:0.01750
# [248]	train-logloss:0.00893	eval-logloss:0.01750
# [249]	train-logloss:0.00888	eval-logloss:0.01739
# [250]	train-logloss:0.00887	eval-logloss:0.01741
# [251]	train-logloss:0.00884	eval-logloss:0.01731
# [252]	train-logloss:0.00879	eval-logloss:0.01716
# [253]	train-logloss:0.00877	eval-logloss:0.01710
# [254]	train-logloss:0.00876	eval-logloss:0.01712
# [255]	train-logloss:0.00871	eval-logloss:0.01698
# [256]	train-logloss:0.00868	eval-logloss:0.01694
# [257]	train-logloss:0.00865	eval-logloss:0.01684
# [258]	train-logloss:0.00860	eval-logloss:0.01674
# [259]	train-logloss:0.00859	eval-logloss:0.01676
# [260]	train-logloss:0.00856	eval-logloss:0.01667
# [261]	train-logloss:0.00852	eval-logloss:0.01651
# [262]	train-logloss:0.00849	eval-logloss:0.01644
# [263]	train-logloss:0.00848	eval-logloss:0.01646
# [264]	train-logloss:0.00845	eval-logloss:0.01647
# [265]	train-logloss:0.00840	eval-logloss:0.01634
# [266]	train-logloss:0.00839	eval-logloss:0.01628
# [267]	train-logloss:0.00836	eval-logloss:0.01619
# [268]	train-logloss:0.00832	eval-logloss:0.01605
# [269]	train-logloss:0.00830	eval-logloss:0.01601
# [270]	train-logloss:0.00828	eval-logloss:0.01603
# [271]	train-logloss:0.00827	eval-logloss:0.01597
# [272]	train-logloss:0.00823	eval-logloss:0.01588
# [273]	train-logloss:0.00822	eval-logloss:0.01590
# [274]	train-logloss:0.00819	eval-logloss:0.01582
# [275]	train-logloss:0.00815	eval-logloss:0.01570
# [276]	train-logloss:0.00814	eval-logloss:0.01564
# [277]	train-logloss:0.00811	eval-logloss:0.01565
# [278]	train-logloss:0.00808	eval-logloss:0.01554
# [279]	train-logloss:0.00805	eval-logloss:0.01548
# [280]	train-logloss:0.00804	eval-logloss:0.01550
# [281]	train-logloss:0.00802	eval-logloss:0.01545
# [282]	train-logloss:0.00800	eval-logloss:0.01537
# [283]	train-logloss:0.00797	eval-logloss:0.01528
# [284]	train-logloss:0.00795	eval-logloss:0.01530
# [285]	train-logloss:0.00794	eval-logloss:0.01528
# [286]	train-logloss:0.00791	eval-logloss:0.01517
# [287]	train-logloss:0.00789	eval-logloss:0.01513
# [288]	train-logloss:0.00788	eval-logloss:0.01514
# [289]	train-logloss:0.00786	eval-logloss:0.01508
# [290]	train-logloss:0.00783	eval-logloss:0.01501
# [291]	train-logloss:0.00781	eval-logloss:0.01503
# [292]	train-logloss:0.00779	eval-logloss:0.01496
# [293]	train-logloss:0.00776	eval-logloss:0.01485
# [294]	train-logloss:0.00775	eval-logloss:0.01484
# [295]	train-logloss:0.00772	eval-logloss:0.01477
# [296]	train-logloss:0.00771	eval-logloss:0.01472
# [297]	train-logloss:0.00770	eval-logloss:0.01474
# [298]	train-logloss:0.00768	eval-logloss:0.01472
# [299]	train-logloss:0.00765	eval-logloss:0.01461
# [300]	train-logloss:0.00764	eval-logloss:0.01454
# [301]	train-logloss:0.00761	eval-logloss:0.01443
# [302]	train-logloss:0.00758	eval-logloss:0.01437
# [303]	train-logloss:0.00757	eval-logloss:0.01435
# [304]	train-logloss:0.00756	eval-logloss:0.01437
# [305]	train-logloss:0.00755	eval-logloss:0.01436
# [306]	train-logloss:0.00754	eval-logloss:0.01429
# [307]	train-logloss:0.00752	eval-logloss:0.01427
# [308]	train-logloss:0.00751	eval-logloss:0.01422
# [309]	train-logloss:0.00749	eval-logloss:0.01424
# [310]	train-logloss:0.00748	eval-logloss:0.01422
# [311]	train-logloss:0.00747	eval-logloss:0.01416
# [312]	train-logloss:0.00746	eval-logloss:0.01412
# [313]	train-logloss:0.00745	eval-logloss:0.01414
# [314]	train-logloss:0.00744	eval-logloss:0.01408
# [315]	train-logloss:0.00743	eval-logloss:0.01407
# [316]	train-logloss:0.00742	eval-logloss:0.01403
# [317]	train-logloss:0.00741	eval-logloss:0.01397
# [318]	train-logloss:0.00740	eval-logloss:0.01399
# [319]	train-logloss:0.00739	eval-logloss:0.01397
# [320]	train-logloss:0.00738	eval-logloss:0.01397
# [321]	train-logloss:0.00737	eval-logloss:0.01391
# [322]	train-logloss:0.00736	eval-logloss:0.01388
# [323]	train-logloss:0.00735	eval-logloss:0.01390
# [324]	train-logloss:0.00734	eval-logloss:0.01385
# [325]	train-logloss:0.00733	eval-logloss:0.01384
# [326]	train-logloss:0.00732	eval-logloss:0.01378
# [327]	train-logloss:0.00731	eval-logloss:0.01379
# [328]	train-logloss:0.00730	eval-logloss:0.01379
# [329]	train-logloss:0.00729	eval-logloss:0.01373
# [330]	train-logloss:0.00728	eval-logloss:0.01369
# [331]	train-logloss:0.00727	eval-logloss:0.01371
# [332]	train-logloss:0.00726	eval-logloss:0.01368
# [333]	train-logloss:0.00725	eval-logloss:0.01364
# [334]	train-logloss:0.00724	eval-logloss:0.01362
# [335]	train-logloss:0.00723	eval-logloss:0.01364
# [336]	train-logloss:0.00722	eval-logloss:0.01358
# [337]	train-logloss:0.00721	eval-logloss:0.01355
# [338]	train-logloss:0.00720	eval-logloss:0.01355
# [339]	train-logloss:0.00719	eval-logloss:0.01349
# [340]	train-logloss:0.00718	eval-logloss:0.01348
# [341]	train-logloss:0.00717	eval-logloss:0.01349
# [342]	train-logloss:0.00716	eval-logloss:0.01349
# [343]	train-logloss:0.00715	eval-logloss:0.01343
# [344]	train-logloss:0.00714	eval-logloss:0.01340
# [345]	train-logloss:0.00713	eval-logloss:0.01341
# [346]	train-logloss:0.00712	eval-logloss:0.01338
# [347]	train-logloss:0.00712	eval-logloss:0.01337
# [348]	train-logloss:0.00711	eval-logloss:0.01331
# [349]	train-logloss:0.00710	eval-logloss:0.01331
# [350]	train-logloss:0.00709	eval-logloss:0.01333
# [351]	train-logloss:0.00708	eval-logloss:0.01330
# [352]	train-logloss:0.00707	eval-logloss:0.01326
# [353]	train-logloss:0.00706	eval-logloss:0.01325
# [354]	train-logloss:0.00705	eval-logloss:0.01319
# [355]	train-logloss:0.00704	eval-logloss:0.01320
# [356]	train-logloss:0.00703	eval-logloss:0.01320
# [357]	train-logloss:0.00702	eval-logloss:0.01317
# [358]	train-logloss:0.00702	eval-logloss:0.01319
# [359]	train-logloss:0.00701	eval-logloss:0.01316
# [360]	train-logloss:0.00700	eval-logloss:0.01310
# [361]	train-logloss:0.00699	eval-logloss:0.01309
# [362]	train-logloss:0.00698	eval-logloss:0.01303
# [363]	train-logloss:0.00697	eval-logloss:0.01303
# [364]	train-logloss:0.00696	eval-logloss:0.01302
# [365]	train-logloss:0.00695	eval-logloss:0.01299
# [366]	train-logloss:0.00695	eval-logloss:0.01300
# [367]	train-logloss:0.00694	eval-logloss:0.01297
# [368]	train-logloss:0.00693	eval-logloss:0.01292
# [369]	train-logloss:0.00692	eval-logloss:0.01293
# [370]	train-logloss:0.00691	eval-logloss:0.01292
# [371]	train-logloss:0.00690	eval-logloss:0.01291
# [372]	train-logloss:0.00689	eval-logloss:0.01288
# [373]	train-logloss:0.00689	eval-logloss:0.01290
# [374]	train-logloss:0.00688	eval-logloss:0.01284
# [375]	train-logloss:0.00687	eval-logloss:0.01281
# [376]	train-logloss:0.00686	eval-logloss:0.01282
# [377]	train-logloss:0.00685	eval-logloss:0.01276
# [378]	train-logloss:0.00684	eval-logloss:0.01275
# [379]	train-logloss:0.00683	eval-logloss:0.01272
# [380]	train-logloss:0.00683	eval-logloss:0.01273
# [381]	train-logloss:0.00682	eval-logloss:0.01273
# [382]	train-logloss:0.00681	eval-logloss:0.01270
# [383]	train-logloss:0.00680	eval-logloss:0.01271
# [384]	train-logloss:0.00679	eval-logloss:0.01270
# [385]	train-logloss:0.00679	eval-logloss:0.01265
# [386]	train-logloss:0.00678	eval-logloss:0.01265
# [387]	train-logloss:0.00677	eval-logloss:0.01264
# [388]	train-logloss:0.00676	eval-logloss:0.01261
# [389]	train-logloss:0.00675	eval-logloss:0.01255
# [390]	train-logloss:0.00675	eval-logloss:0.01257
# [391]	train-logloss:0.00674	eval-logloss:0.01256
# [392]	train-logloss:0.00673	eval-logloss:0.01257
# [393]	train-logloss:0.00672	eval-logloss:0.01255
# [394]	train-logloss:0.00671	eval-logloss:0.01253
# [395]	train-logloss:0.00671	eval-logloss:0.01248
# [396]	train-logloss:0.00670	eval-logloss:0.01249
# [397]	train-logloss:0.00669	eval-logloss:0.01250
# [398]	train-logloss:0.00668	eval-logloss:0.01245
# [399]	train-logloss:0.00668	eval-logloss:0.01245

# %%
pred_probs = xgb_model.predict(dtest)
print('predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5보다 크면 1, 그렇지 않으면 0으로 예측값 결정하여 List 객체인 preds에 저장
preds = [1 if x>0.5 else 0 for x in pred_probs]
print('예측값 10개만 표시:', preds[:10])
# Out:
# predict() 수행 결괏값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.907 0.003 0.906 0.182 0.993 1.    1.    0.999 0.995 0.   ]
# 예측값 10개만 표시: [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
def get_clf_eval(y_test, pred, pred_proba):
  confusion=confusion_matrix(y_test,pred)
  accuracy=accuracy_score(y_test, pred)
  precision=precision_score(y_test, pred)
  recall=recall_score(y_test,pred)
  f1=f1_score(y_test, pred)
  roc_auc=roc_auc_score(y_test,pred)
  print('오차행렬')
  print(confusion)
  print('정확도:{0:.4f},정밀도:{1:.4f},재현율:{2:.4f},F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy,precision,recall,f1,roc_auc))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
get_clf_eval(y_test, preds, pred_probs)
# Out:
# 오차행렬
# [[34  3]
#  [ 1 76]]
# 정확도:0.9649,정밀도:0.9620,재현율:0.9870,F1:0.9744, AUC:0.9530

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

# Warning 메시지를 없애기 위해 eval_metric 값을 XGBClassifier 생성 인자로 입력.
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3,
                            eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train, verbose=True)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# 오차행렬
# [[34  3]
#  [ 1 76]]
# 정확도:0.9649,정밀도:0.9620,재현율:0.9870,F1:0.9744, AUC:0.9530

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3,
                            early_stopping_rounds=50,eval_metric='logloss')
evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, eval_set=evals, verbose=True)
ws50_preds = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.62473	validation_1-logloss:0.63088
# [1]	validation_0-logloss:0.58662	validation_1-logloss:0.60461
# [2]	validation_0-logloss:0.55210	validation_1-logloss:0.58205
# [3]	validation_0-logloss:0.52068	validation_1-logloss:0.56165
# [4]	validation_0-logloss:0.49173	validation_1-logloss:0.54101
# [5]	validation_0-logloss:0.46517	validation_1-logloss:0.52206
# [6]	validation_0-logloss:0.44009	validation_1-logloss:0.50271
# [7]	validation_0-logloss:0.41646	validation_1-logloss:0.48606
# [8]	validation_0-logloss:0.39505	validation_1-logloss:0.46961
# [9]	validation_0-logloss:0.37523	validation_1-logloss:0.45485
# [10]	validation_0-logloss:0.35682	validation_1-logloss:0.44120
# [11]	validation_0-logloss:0.33964	validation_1-logloss:0.43123
# [12]	validation_0-logloss:0.32279	validation_1-logloss:0.41962
# [13]	validation_0-logloss:0.30783	validation_1-logloss:0.40848
# [14]	validation_0-logloss:0.29308	validation_1-logloss:0.39857
# [15]	validation_0-logloss:0.27928	validation_1-logloss:0.38945
# [16]	validation_0-logloss:0.26681	validation_1-logloss:0.38171
# [17]	validation_0-logloss:0.25498	validation_1-logloss:0.37381
# [18]	validation_0-logloss:0.24352	validation_1-logloss:0.36656
# [19]	validation_0-logloss:0.23307	validation_1-logloss:0.36014
# [20]	validation_0-logloss:0.22290	validation_1-logloss:0.35395
# [21]	validation_0-logloss:0.21335	validation_1-logloss:0.34726
# [22]	validation_0-logloss:0.20461	validation_1-logloss:0.34194
# [23]	validation_0-logloss:0.19610	validation_1-logloss:0.33611
# [24]	validation_0-logloss:0.18807	validation_1-logloss:0.33170
# [25]	validation_0-logloss:0.18054	validation_1-logloss:0.32730
# [26]	validation_0-logloss:0.17336	validation_1-logloss:0.32357
# [27]	validation_0-logloss:0.16659	validation_1-logloss:0.31915
# [28]	validation_0-logloss:0.16021	validation_1-logloss:0.31569
# [29]	validation_0-logloss:0.15417	validation_1-logloss:0.31236
# [30]	validation_0-logloss:0.14843	validation_1-logloss:0.30978
# [31]	validation_0-logloss:0.14298	validation_1-logloss:0.30645
# [32]	validation_0-logloss:0.13788	validation_1-logloss:0.30403
# [33]	validation_0-logloss:0.13299	validation_1-logloss:0.30108
# [34]	validation_0-logloss:0.12824	validation_1-logloss:0.29780
# [35]	validation_0-logloss:0.12392	validation_1-logloss:0.29599
# [36]	validation_0-logloss:0.11965	validation_1-logloss:0.29444
# [37]	validation_0-logloss:0.11549	validation_1-logloss:0.29141
# [38]	validation_0-logloss:0.11168	validation_1-logloss:0.28951
# [39]	validation_0-logloss:0.10797	validation_1-logloss:0.28751
# [40]	validation_0-logloss:0.10458	validation_1-logloss:0.28600
# [41]	validation_0-logloss:0.10116	validation_1-logloss:0.28381
# [42]	validation_0-logloss:0.09801	validation_1-logloss:0.28226
# [43]	validation_0-logloss:0.09494	validation_1-logloss:0.28086
# [44]	validation_0-logloss:0.09211	validation_1-logloss:0.27937
# [45]	validation_0-logloss:0.08939	validation_1-logloss:0.27746
# [46]	validation_0-logloss:0.08688	validation_1-logloss:0.27717
# [47]	validation_0-logloss:0.08441	validation_1-logloss:0.27523
# [48]	validation_0-logloss:0.08205	validation_1-logloss:0.27367
# [49]	validation_0-logloss:0.07981	validation_1-logloss:0.27254
# [50]	validation_0-logloss:0.07767	validation_1-logloss:0.27090
# [51]	validation_0-logloss:0.07565	validation_1-logloss:0.26996
# [52]	validation_0-logloss:0.07354	validation_1-logloss:0.26984
# [53]	validation_0-logloss:0.07169	validation_1-logloss:0.26846
# [54]	validation_0-logloss:0.06994	validation_1-logloss:0.26778
# [55]	validation_0-logloss:0.06822	validation_1-logloss:0.26653
# [56]	validation_0-logloss:0.06661	validation_1-logloss:0.26614
# [57]	validation_0-logloss:0.06509	validation_1-logloss:0.26509
# [58]	validation_0-logloss:0.06359	validation_1-logloss:0.26497
# [59]	validation_0-logloss:0.06218	validation_1-logloss:0.26424
# [60]	validation_0-logloss:0.06056	validation_1-logloss:0.26369
# [61]	validation_0-logloss:0.05909	validation_1-logloss:0.26197
# [62]	validation_0-logloss:0.05782	validation_1-logloss:0.26091
# [63]	validation_0-logloss:0.05648	validation_1-logloss:0.25936
# [64]	validation_0-logloss:0.05511	validation_1-logloss:0.25881
# [65]	validation_0-logloss:0.05383	validation_1-logloss:0.25837
# [66]	validation_0-logloss:0.05257	validation_1-logloss:0.25740
# [67]	validation_0-logloss:0.05132	validation_1-logloss:0.25701
# [68]	validation_0-logloss:0.05034	validation_1-logloss:0.25595
# [69]	validation_0-logloss:0.04901	validation_1-logloss:0.25522
# [70]	validation_0-logloss:0.04804	validation_1-logloss:0.25551
# [71]	validation_0-logloss:0.04702	validation_1-logloss:0.25487
# [72]	validation_0-logloss:0.04614	validation_1-logloss:0.25409
# [73]	validation_0-logloss:0.04518	validation_1-logloss:0.25447
# [74]	validation_0-logloss:0.04426	validation_1-logloss:0.25393
# [75]	validation_0-logloss:0.04337	validation_1-logloss:0.25386
# [76]	validation_0-logloss:0.04252	validation_1-logloss:0.25397
# [77]	validation_0-logloss:0.04168	validation_1-logloss:0.25278
# [78]	validation_0-logloss:0.04082	validation_1-logloss:0.25285
# [79]	validation_0-logloss:0.04005	validation_1-logloss:0.25188
# [80]	validation_0-logloss:0.03926	validation_1-logloss:0.25276
# [81]	validation_0-logloss:0.03849	validation_1-logloss:0.25294
# [82]	validation_0-logloss:0.03774	validation_1-logloss:0.25376
# [83]	validation_0-logloss:0.03712	validation_1-logloss:0.25441
# [84]	validation_0-logloss:0.03648	validation_1-logloss:0.25474
# [85]	validation_0-logloss:0.03578	validation_1-logloss:0.25497
# [86]	validation_0-logloss:0.03523	validation_1-logloss:0.25566
# [87]	validation_0-logloss:0.03458	validation_1-logloss:0.25602
# [88]	validation_0-logloss:0.03396	validation_1-logloss:0.25629
# [89]	validation_0-logloss:0.03336	validation_1-logloss:0.25574
# [90]	validation_0-logloss:0.03287	validation_1-logloss:0.25647
# [91]	validation_0-logloss:0.03230	validation_1-logloss:0.25598
# [92]	validation_0-logloss:0.03175	validation_1-logloss:0.25617
# [93]	validation_0-logloss:0.03127	validation_1-logloss:0.25538
# [94]	validation_0-logloss:0.03077	validation_1-logloss:0.25641
# [95]	validation_0-logloss:0.03026	validation_1-logloss:0.25600
# [96]	validation_0-logloss:0.02978	validation_1-logloss:0.25560
# [97]	validation_0-logloss:0.02938	validation_1-logloss:0.25513
# [98]	validation_0-logloss:0.02889	validation_1-logloss:0.25448
# [99]	validation_0-logloss:0.02844	validation_1-logloss:0.25416
# [100]	validation_0-logloss:0.02802	validation_1-logloss:0.25385
# [101]	validation_0-logloss:0.02764	validation_1-logloss:0.25426
# [102]	validation_0-logloss:0.02724	validation_1-logloss:0.25400
# [103]	validation_0-logloss:0.02685	validation_1-logloss:0.25220
# [104]	validation_0-logloss:0.02648	validation_1-logloss:0.25196
# [105]	validation_0-logloss:0.02611	validation_1-logloss:0.25253
# [106]	validation_0-logloss:0.02578	validation_1-logloss:0.25141
# [107]	validation_0-logloss:0.02542	validation_1-logloss:0.25168
# [108]	validation_0-logloss:0.02509	validation_1-logloss:0.25203
# [109]	validation_0-logloss:0.02476	validation_1-logloss:0.25219
# [110]	validation_0-logloss:0.02441	validation_1-logloss:0.25187
# [111]	validation_0-logloss:0.02403	validation_1-logloss:0.25063
# [112]	validation_0-logloss:0.02372	validation_1-logloss:0.25121
# [113]	validation_0-logloss:0.02339	validation_1-logloss:0.24862
# [114]	validation_0-logloss:0.02310	validation_1-logloss:0.24922
# [115]	validation_0-logloss:0.02279	validation_1-logloss:0.24903
# [116]	validation_0-logloss:0.02248	validation_1-logloss:0.24924
# [117]	validation_0-logloss:0.02217	validation_1-logloss:0.24756
# [118]	validation_0-logloss:0.02191	validation_1-logloss:0.24720
# [119]	validation_0-logloss:0.02162	validation_1-logloss:0.24566
# [120]	validation_0-logloss:0.02134	validation_1-logloss:0.24629
# [121]	validation_0-logloss:0.02105	validation_1-logloss:0.24693
# [122]	validation_0-logloss:0.02078	validation_1-logloss:0.24755
# [123]	validation_0-logloss:0.02056	validation_1-logloss:0.24753
# [124]	validation_0-logloss:0.02030	validation_1-logloss:0.24738
# [125]	validation_0-logloss:0.02007	validation_1-logloss:0.24705
# [126]	validation_0-logloss:0.01984	validation_1-logloss:0.24741
# [127]	validation_0-logloss:0.01961	validation_1-logloss:0.24802
# [128]	validation_0-logloss:0.01940	validation_1-logloss:0.24716
# [129]	validation_0-logloss:0.01916	validation_1-logloss:0.24701
# [130]	validation_0-logloss:0.01896	validation_1-logloss:0.24752
# [131]	validation_0-logloss:0.01872	validation_1-logloss:0.24758
# [132]	validation_0-logloss:0.01853	validation_1-logloss:0.24849
# [133]	validation_0-logloss:0.01834	validation_1-logloss:0.24890
# [134]	validation_0-logloss:0.01820	validation_1-logloss:0.24902
# [135]	validation_0-logloss:0.01799	validation_1-logloss:0.24769
# [136]	validation_0-logloss:0.01778	validation_1-logloss:0.24756
# [137]	validation_0-logloss:0.01761	validation_1-logloss:0.24762
# [138]	validation_0-logloss:0.01747	validation_1-logloss:0.24686
# [139]	validation_0-logloss:0.01730	validation_1-logloss:0.24724
# [140]	validation_0-logloss:0.01710	validation_1-logloss:0.24713
# [141]	validation_0-logloss:0.01696	validation_1-logloss:0.24720
# [142]	validation_0-logloss:0.01680	validation_1-logloss:0.24761
# [143]	validation_0-logloss:0.01662	validation_1-logloss:0.24731
# [144]	validation_0-logloss:0.01649	validation_1-logloss:0.24659
# [145]	validation_0-logloss:0.01634	validation_1-logloss:0.24643
# [146]	validation_0-logloss:0.01617	validation_1-logloss:0.24615
# [147]	validation_0-logloss:0.01606	validation_1-logloss:0.24626
# [148]	validation_0-logloss:0.01591	validation_1-logloss:0.24614
# [149]	validation_0-logloss:0.01579	validation_1-logloss:0.24545
# [150]	validation_0-logloss:0.01562	validation_1-logloss:0.24621
# [151]	validation_0-logloss:0.01549	validation_1-logloss:0.24607
# [152]	validation_0-logloss:0.01532	validation_1-logloss:0.24596
# [153]	validation_0-logloss:0.01521	validation_1-logloss:0.24530
# [154]	validation_0-logloss:0.01505	validation_1-logloss:0.24583
# [155]	validation_0-logloss:0.01493	validation_1-logloss:0.24570
# [156]	validation_0-logloss:0.01476	validation_1-logloss:0.24642
# [157]	validation_0-logloss:0.01462	validation_1-logloss:0.24623
# [158]	validation_0-logloss:0.01447	validation_1-logloss:0.24670
# [159]	validation_0-logloss:0.01435	validation_1-logloss:0.24659
# [160]	validation_0-logloss:0.01423	validation_1-logloss:0.24548
# [161]	validation_0-logloss:0.01415	validation_1-logloss:0.24485
# [162]	validation_0-logloss:0.01399	validation_1-logloss:0.24547
# [163]	validation_0-logloss:0.01387	validation_1-logloss:0.24545
# [164]	validation_0-logloss:0.01372	validation_1-logloss:0.24608
# [165]	validation_0-logloss:0.01359	validation_1-logloss:0.24507
# [166]	validation_0-logloss:0.01351	validation_1-logloss:0.24484
# [167]	validation_0-logloss:0.01340	validation_1-logloss:0.24484
# [168]	validation_0-logloss:0.01326	validation_1-logloss:0.24547
# [169]	validation_0-logloss:0.01315	validation_1-logloss:0.24443
# [170]	validation_0-logloss:0.01305	validation_1-logloss:0.24488
# [171]	validation_0-logloss:0.01297	validation_1-logloss:0.24478
# [172]	validation_0-logloss:0.01289	validation_1-logloss:0.24422
# [173]	validation_0-logloss:0.01282	validation_1-logloss:0.24414
# [174]	validation_0-logloss:0.01272	validation_1-logloss:0.24317
# [175]	validation_0-logloss:0.01263	validation_1-logloss:0.24326
# [176]	validation_0-logloss:0.01256	validation_1-logloss:0.24273
# [177]	validation_0-logloss:0.01247	validation_1-logloss:0.24262
# [178]	validation_0-logloss:0.01237	validation_1-logloss:0.24309
# [179]	validation_0-logloss:0.01231	validation_1-logloss:0.24250
# [180]	validation_0-logloss:0.01224	validation_1-logloss:0.24243
# [181]	validation_0-logloss:0.01215	validation_1-logloss:0.24148
# [182]	validation_0-logloss:0.01206	validation_1-logloss:0.24136
# [183]	validation_0-logloss:0.01199	validation_1-logloss:0.24130
# [184]	validation_0-logloss:0.01191	validation_1-logloss:0.24141
# [185]	validation_0-logloss:0.01183	validation_1-logloss:0.24045
# [186]	validation_0-logloss:0.01177	validation_1-logloss:0.23950
# [187]	validation_0-logloss:0.01171	validation_1-logloss:0.23946
# [188]	validation_0-logloss:0.01165	validation_1-logloss:0.23943
# [189]	validation_0-logloss:0.01156	validation_1-logloss:0.23954
# [190]	validation_0-logloss:0.01151	validation_1-logloss:0.23897
# [191]	validation_0-logloss:0.01145	validation_1-logloss:0.23961
# [192]	validation_0-logloss:0.01138	validation_1-logloss:0.23972
# [193]	validation_0-logloss:0.01133	validation_1-logloss:0.23968
# [194]	validation_0-logloss:0.01128	validation_1-logloss:0.23913
# [195]	validation_0-logloss:0.01121	validation_1-logloss:0.23924
# [196]	validation_0-logloss:0.01118	validation_1-logloss:0.23902
# [197]	validation_0-logloss:0.01113	validation_1-logloss:0.23900
# [198]	validation_0-logloss:0.01106	validation_1-logloss:0.23912
# [199]	validation_0-logloss:0.01101	validation_1-logloss:0.23824
# [200]	validation_0-logloss:0.01096	validation_1-logloss:0.23802
# [201]	validation_0-logloss:0.01090	validation_1-logloss:0.23814
# [202]	validation_0-logloss:0.01086	validation_1-logloss:0.23762
# [203]	validation_0-logloss:0.01080	validation_1-logloss:0.23740
# [204]	validation_0-logloss:0.01074	validation_1-logloss:0.23752
# [205]	validation_0-logloss:0.01069	validation_1-logloss:0.23793
# [206]	validation_0-logloss:0.01064	validation_1-logloss:0.23797
# [207]	validation_0-logloss:0.01058	validation_1-logloss:0.23803
# [208]	validation_0-logloss:0.01054	validation_1-logloss:0.23782
# [209]	validation_0-logloss:0.01048	validation_1-logloss:0.23793
# [210]	validation_0-logloss:0.01045	validation_1-logloss:0.23773
# [211]	validation_0-logloss:0.01041	validation_1-logloss:0.23814
# [212]	validation_0-logloss:0.01036	validation_1-logloss:0.23817
# [213]	validation_0-logloss:0.01031	validation_1-logloss:0.23866
# [214]	validation_0-logloss:0.01027	validation_1-logloss:0.23926
# [215]	validation_0-logloss:0.01025	validation_1-logloss:0.23907
# [216]	validation_0-logloss:0.01019	validation_1-logloss:0.23842
# [217]	validation_0-logloss:0.01014	validation_1-logloss:0.23845
# [218]	validation_0-logloss:0.01011	validation_1-logloss:0.23866
# [219]	validation_0-logloss:0.01009	validation_1-logloss:0.23842
# [220]	validation_0-logloss:0.01007	validation_1-logloss:0.23823
# [221]	validation_0-logloss:0.01003	validation_1-logloss:0.23844
# [222]	validation_0-logloss:0.01001	validation_1-logloss:0.23836
# [223]	validation_0-logloss:0.00996	validation_1-logloss:0.23855
# [224]	validation_0-logloss:0.00993	validation_1-logloss:0.23876
# [225]	validation_0-logloss:0.00991	validation_1-logloss:0.23857
# [226]	validation_0-logloss:0.00989	validation_1-logloss:0.23833
# [227]	validation_0-logloss:0.00986	validation_1-logloss:0.23855
# [228]	validation_0-logloss:0.00984	validation_1-logloss:0.23837
# [229]	validation_0-logloss:0.00982	validation_1-logloss:0.23813
# [230]	validation_0-logloss:0.00979	validation_1-logloss:0.23862
# [231]	validation_0-logloss:0.00977	validation_1-logloss:0.23844
# [232]	validation_0-logloss:0.00975	validation_1-logloss:0.23836
# [233]	validation_0-logloss:0.00971	validation_1-logloss:0.23882
# [234]	validation_0-logloss:0.00968	validation_1-logloss:0.23935
# [235]	validation_0-logloss:0.00962	validation_1-logloss:0.23870
# [236]	validation_0-logloss:0.00958	validation_1-logloss:0.23873
# [237]	validation_0-logloss:0.00956	validation_1-logloss:0.23855
# [238]	validation_0-logloss:0.00953	validation_1-logloss:0.23877
# [239]	validation_0-logloss:0.00952	validation_1-logloss:0.23854
# [240]	validation_0-logloss:0.00950	validation_1-logloss:0.23901
# [241]	validation_0-logloss:0.00948	validation_1-logloss:0.23899
# [242]	validation_0-logloss:0.00947	validation_1-logloss:0.23881
# [243]	validation_0-logloss:0.00944	validation_1-logloss:0.23903
# [244]	validation_0-logloss:0.00942	validation_1-logloss:0.23895
# [245]	validation_0-logloss:0.00938	validation_1-logloss:0.23951
# [246]	validation_0-logloss:0.00934	validation_1-logloss:0.23996
# [247]	validation_0-logloss:0.00932	validation_1-logloss:0.23978
# [248]	validation_0-logloss:0.00930	validation_1-logloss:0.24030
# [249]	validation_0-logloss:0.00928	validation_1-logloss:0.24008
# [250]	validation_0-logloss:0.00926	validation_1-logloss:0.24054
# [251]	validation_0-logloss:0.00925	validation_1-logloss:0.24046
# [252]	validation_0-logloss:0.00921	validation_1-logloss:0.24055
# [253]	validation_0-logloss:0.00919	validation_1-logloss:0.24053

# %%
get_clf_eval(y_test, ws50_preds, ws50_pred_proba)
# Out:
# 오차행렬
# [[35  2]
#  [ 2 75]]
# 정확도:0.9649,정밀도:0.9740,재현율:0.9740,F1:0.9740, AUC:0.9600

# %%
# early_stopping_rounds를 10으로 설정하고 재학습.
xgb_wrapper=XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3, early_stopping_rounds=10, eval_metric='logloss')
xgb_wrapper.fit(X_tr,y_tr, eval_set=evals, verbose=True)
ws10_preds=xgb_wrapper.predict(X_test)
ws10_preds_proba=xgb_wrapper.predict_proba(X_test)[:,1]
get_clf_eval(y_test, ws10_preds, ws10_preds_proba)
# Out:
# [0]	validation_0-logloss:0.62473	validation_1-logloss:0.63088
# [1]	validation_0-logloss:0.58662	validation_1-logloss:0.60461
# [2]	validation_0-logloss:0.55210	validation_1-logloss:0.58205
# [3]	validation_0-logloss:0.52068	validation_1-logloss:0.56165
# [4]	validation_0-logloss:0.49173	validation_1-logloss:0.54101
# [5]	validation_0-logloss:0.46517	validation_1-logloss:0.52206
# [6]	validation_0-logloss:0.44009	validation_1-logloss:0.50271
# [7]	validation_0-logloss:0.41646	validation_1-logloss:0.48606
# [8]	validation_0-logloss:0.39505	validation_1-logloss:0.46961
# [9]	validation_0-logloss:0.37523	validation_1-logloss:0.45485
# [10]	validation_0-logloss:0.35682	validation_1-logloss:0.44120
# [11]	validation_0-logloss:0.33964	validation_1-logloss:0.43123
# [12]	validation_0-logloss:0.32279	validation_1-logloss:0.41962
# [13]	validation_0-logloss:0.30783	validation_1-logloss:0.40848
# [14]	validation_0-logloss:0.29308	validation_1-logloss:0.39857
# [15]	validation_0-logloss:0.27928	validation_1-logloss:0.38945
# [16]	validation_0-logloss:0.26681	validation_1-logloss:0.38171
# [17]	validation_0-logloss:0.25498	validation_1-logloss:0.37381
# [18]	validation_0-logloss:0.24352	validation_1-logloss:0.36656
# [19]	validation_0-logloss:0.23307	validation_1-logloss:0.36014
# [20]	validation_0-logloss:0.22290	validation_1-logloss:0.35395
# [21]	validation_0-logloss:0.21335	validation_1-logloss:0.34726
# [22]	validation_0-logloss:0.20461	validation_1-logloss:0.34194
# [23]	validation_0-logloss:0.19610	validation_1-logloss:0.33611
# [24]	validation_0-logloss:0.18807	validation_1-logloss:0.33170
# [25]	validation_0-logloss:0.18054	validation_1-logloss:0.32730
# [26]	validation_0-logloss:0.17336	validation_1-logloss:0.32357
# [27]	validation_0-logloss:0.16659	validation_1-logloss:0.31915
# [28]	validation_0-logloss:0.16021	validation_1-logloss:0.31569
# [29]	validation_0-logloss:0.15417	validation_1-logloss:0.31236
# [30]	validation_0-logloss:0.14843	validation_1-logloss:0.30978
# [31]	validation_0-logloss:0.14298	validation_1-logloss:0.30645
# [32]	validation_0-logloss:0.13788	validation_1-logloss:0.30403
# [33]	validation_0-logloss:0.13299	validation_1-logloss:0.30108
# [34]	validation_0-logloss:0.12824	validation_1-logloss:0.29780
# [35]	validation_0-logloss:0.12392	validation_1-logloss:0.29599
# [36]	validation_0-logloss:0.11965	validation_1-logloss:0.29444
# [37]	validation_0-logloss:0.11549	validation_1-logloss:0.29141
# [38]	validation_0-logloss:0.11168	validation_1-logloss:0.28951
# [39]	validation_0-logloss:0.10797	validation_1-logloss:0.28751
# [40]	validation_0-logloss:0.10458	validation_1-logloss:0.28600
# [41]	validation_0-logloss:0.10116	validation_1-logloss:0.28381
# [42]	validation_0-logloss:0.09801	validation_1-logloss:0.28226
# [43]	validation_0-logloss:0.09494	validation_1-logloss:0.28086
# [44]	validation_0-logloss:0.09211	validation_1-logloss:0.27937
# [45]	validation_0-logloss:0.08939	validation_1-logloss:0.27746
# [46]	validation_0-logloss:0.08688	validation_1-logloss:0.27717
# [47]	validation_0-logloss:0.08441	validation_1-logloss:0.27523
# [48]	validation_0-logloss:0.08205	validation_1-logloss:0.27367
# [49]	validation_0-logloss:0.07981	validation_1-logloss:0.27254
# [50]	validation_0-logloss:0.07767	validation_1-logloss:0.27090
# [51]	validation_0-logloss:0.07565	validation_1-logloss:0.26996
# [52]	validation_0-logloss:0.07354	validation_1-logloss:0.26984
# [53]	validation_0-logloss:0.07169	validation_1-logloss:0.26846
# [54]	validation_0-logloss:0.06994	validation_1-logloss:0.26778
# [55]	validation_0-logloss:0.06822	validation_1-logloss:0.26653
# [56]	validation_0-logloss:0.06661	validation_1-logloss:0.26614
# [57]	validation_0-logloss:0.06509	validation_1-logloss:0.26509
# [58]	validation_0-logloss:0.06359	validation_1-logloss:0.26497
# [59]	validation_0-logloss:0.06218	validation_1-logloss:0.26424
# [60]	validation_0-logloss:0.06056	validation_1-logloss:0.26369
# [61]	validation_0-logloss:0.05909	validation_1-logloss:0.26197
# [62]	validation_0-logloss:0.05782	validation_1-logloss:0.26091
# [63]	validation_0-logloss:0.05648	validation_1-logloss:0.25936
# [64]	validation_0-logloss:0.05511	validation_1-logloss:0.25881
# [65]	validation_0-logloss:0.05383	validation_1-logloss:0.25837
# [66]	validation_0-logloss:0.05257	validation_1-logloss:0.25740
# [67]	validation_0-logloss:0.05132	validation_1-logloss:0.25701
# [68]	validation_0-logloss:0.05034	validation_1-logloss:0.25595
# [69]	validation_0-logloss:0.04901	validation_1-logloss:0.25522
# [70]	validation_0-logloss:0.04804	validation_1-logloss:0.25551
# [71]	validation_0-logloss:0.04702	validation_1-logloss:0.25487
# [72]	validation_0-logloss:0.04614	validation_1-logloss:0.25409
# [73]	validation_0-logloss:0.04518	validation_1-logloss:0.25447
# [74]	validation_0-logloss:0.04426	validation_1-logloss:0.25393
# [75]	validation_0-logloss:0.04337	validation_1-logloss:0.25386
# [76]	validation_0-logloss:0.04252	validation_1-logloss:0.25397
# [77]	validation_0-logloss:0.04168	validation_1-logloss:0.25278
# [78]	validation_0-logloss:0.04082	validation_1-logloss:0.25285
# [79]	validation_0-logloss:0.04005	validation_1-logloss:0.25188
# [80]	validation_0-logloss:0.03926	validation_1-logloss:0.25276
# [81]	validation_0-logloss:0.03849	validation_1-logloss:0.25294
# [82]	validation_0-logloss:0.03774	validation_1-logloss:0.25376
# [83]	validation_0-logloss:0.03712	validation_1-logloss:0.25441
# [84]	validation_0-logloss:0.03648	validation_1-logloss:0.25474
# [85]	validation_0-logloss:0.03578	validation_1-logloss:0.25497
# [86]	validation_0-logloss:0.03523	validation_1-logloss:0.25566
# [87]	validation_0-logloss:0.03458	validation_1-logloss:0.25602
# [88]	validation_0-logloss:0.03396	validation_1-logloss:0.25629
# [89]	validation_0-logloss:0.03336	validation_1-logloss:0.25574
# 오차행렬
# [[36  1]
#  [ 2 75]]
# 정확도:0.9737,정밀도:0.9868,재현율:0.9740,F1:0.9804, AUC:0.9735

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방.
plot_importance(xgb_wrapper, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>
